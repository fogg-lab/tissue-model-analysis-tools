# %%
import tensorflow.keras.backend as K
import numpy as np
import pandas as pd
import json
import multiprocessing
import matplotlib.pyplot as plt

from glob import glob
from copy import deepcopy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# 2022-05-11 10:51:45.632782: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
n_cores = multiprocessing.cpu_count()
n_cores
# Out:
# 20

# %%
from fl_tissue_model_tools import data_prep, dev_config, models, defs
import fl_tissue_model_tools.preprocessing as prep

# %%
dirs = dev_config.get_dev_directories("../../dev_paths.txt")

# %% [markdown]
# # Set up model training parameters

# %%
with open("../../model_training/invasion_depth_training_values.json", 'r') as fp:
    training_values = json.load(fp)
training_values["rs_seed"] = None if (training_values["rs_seed"] == "None") else training_values["rs_seed"]

# %%
training_values
# Out:
# {'batch_size': 32,
#  'frozen_epochs': 50,
#  'fine_tune_epochs': 50,
#  'val_split': 0.2,
#  'early_stopping_patience': 25,
#  'early_stopping_min_delta': 0.0001,
#  'rs_seed': None,
#  'resnet_inp_shape': [128, 128, 3],
#  'class_labels': {'no_invasion': 0, 'invasion': 1},
#  'cls_thresh': 0.5,
#  'n_models': 5}

# %%
with open("../../model_training/invasion_depth_best_hp.json", 'r') as fp:
    best_hp = json.load(fp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
#       1 with open("../model_training/invasion_depth_best_hp.json", 'r') as fp:
# ----> 2     best_hp = json.load(fp)
#
# NameError: name 'json' is not defined

# %%
best_hp
# Out:
# {'adam_beta_1': 0.8690806056354333,
#  'adam_beta_2': 0.9817045929249536,
#  'fine_tune_lr': 4.837200625807212e-05,
#  'frozen_lr': 0.00023296415902195254,
#  'last_resnet_layer': 'conv5_block1_out'}

# %%
### Data paths ###
root_data_path = f"{dirs.data_dir}/invasion_data/"
model_training_path = f"{dirs.analysis_dir}/resnet50_invasion_model"
best_ensemble_training_path = f"{model_training_path}/best_ensemble"


### Model building & training parameters ###
resnet_inp_shape = tuple(training_values["resnet_inp_shape"])
class_labels = training_values["class_labels"]
n_models = training_values["n_models"]
# Binary classification -> only need 1 output unit
n_outputs = 1

seed = training_values["rs_seed"]
val_split = training_values["val_split"]
batch_size = training_values["batch_size"]
frozen_epochs = training_values["frozen_epochs"]
fine_tune_epochs = training_values["fine_tune_epochs"]
# frozen_epochs = 5
# fine_tune_epochs = 5
adam_beta_1 = best_hp["adam_beta_1"]
adam_beta_2 = best_hp["adam_beta_2"]
frozen_lr = best_hp["frozen_lr"]
fine_tune_lr = best_hp["fine_tune_lr"]
last_resnet_layer = best_hp["last_resnet_layer"]


### Early stopping ###
es_criterion = "val_loss"
es_mode = "min"
# Update these depending on seriousness of experiment
es_patience = training_values["early_stopping_patience"]
es_min_delta = training_values["early_stopping_min_delta"]


### Model saving ###
mcp_criterion = "val_loss"
mcp_mode = "min"
mcp_best_only = True
# Need to set to True otherwise base model "layer" won't save/load properly
mcp_weights_only = True

# %%
data_prep.make_dir(best_ensemble_training_path)

# %%
rs = np.random.RandomState(seed)

# %% [markdown]
# # Train ensemble of models using best hyperparameters

# %%
for model_idx in range(n_models):
    print(f"Training model {model_idx}...")
    ### Prepare data (each model should be trained on a randomly assigned train/validation set) ###
    # Training & validation data (drawn from same image set & randomly assigned)
    tv_class_paths = {v: glob(f"{root_data_path}/train/{k}/*.tif") for k, v in class_labels.items()}
    mcp_best_frozen_weights_file = f"{best_ensemble_training_path}/best_frozen_weights_{model_idx}.h5"
    mcp_best_finetune_weights_file = f"{best_ensemble_training_path}/best_finetune_weights_{model_idx}.h5"

    for k, v in tv_class_paths.items():
        rs.shuffle(v)

    train_data_paths, val_data_paths = data_prep.get_train_val_split(tv_class_paths, val_split=val_split)


    ### Build datasets ###
    train_datagen = data_prep.InvasionDataGenerator(
        train_data_paths,
        class_labels,
        batch_size,
        resnet_inp_shape[:2],
        rs,
        class_weights=True,
        shuffle=True,
        augmentation_function=prep.augment_imgs
    )
    val_datagen = data_prep.InvasionDataGenerator(
        val_data_paths,
        class_labels,
        batch_size,
        resnet_inp_shape[:2],
        rs,
        class_weights=train_datagen.class_weights,
        shuffle=True,
        augmentation_function=train_datagen.augmentation_function
    )


    ### Build model ###
    K.clear_session()
    tl_model = models.build_ResNet50_TL(
        n_outputs,
        resnet_inp_shape,
        base_last_layer=last_resnet_layer,
        base_model_trainable=False
    )


    ### Frozen training ###
    tl_model.compile(
        optimizer=Adam(learning_rate=frozen_lr, beta_1=adam_beta_1, beta_2=adam_beta_2),
        loss=BinaryCrossentropy(),
        weighted_metrics=[BinaryAccuracy()]
    )

    es_callback = EarlyStopping(monitor=es_criterion, mode=es_mode, min_delta=es_min_delta, patience=es_patience)
    mcp_callback = ModelCheckpoint(mcp_best_frozen_weights_file, monitor=mcp_criterion, mode=mcp_mode, save_best_only=mcp_best_only, save_weights_only=mcp_weights_only)

    h1 = tl_model.fit(
        train_datagen,
        validation_data=val_datagen,
        epochs=frozen_epochs,
        callbacks=[es_callback, mcp_callback],
        workers=n_cores
    )


    ### Finetune training ###
    # Load best frozen weights before fine tuning
    tl_model.load_weights(mcp_best_frozen_weights_file)
    # Make base model trainable
    models.toggle_TL_freeze(tl_model)
    tl_model.compile(
        optimizer=Adam(learning_rate=fine_tune_lr, beta_1=adam_beta_1, beta_2=adam_beta_2),
        loss=BinaryCrossentropy(),
        weighted_metrics=[BinaryAccuracy()]
    )

    es_callback = EarlyStopping(monitor=es_criterion, mode=es_mode, min_delta=es_min_delta, patience=es_patience)
    mcp_callback = ModelCheckpoint(mcp_best_finetune_weights_file, monitor=mcp_criterion, mode=mcp_mode, save_best_only=mcp_best_only, save_weights_only=mcp_weights_only)

    h2 = tl_model.fit(
        train_datagen,
        validation_data=val_datagen,
        epochs=fine_tune_epochs,
        callbacks=[es_callback, mcp_callback],
        workers=n_cores
    )


    ### Save results for comparison later ###
    h1_df = pd.DataFrame(h1.history)
    h1_df["training_stage"] = ["frozen"] * len(h1.epoch)

    h2_df = pd.DataFrame(h2.history)
    h2_df["training_stage"] = ["finetune"] * len(h2.epoch)

    h_df = pd.concat([h1_df, h2_df], axis=0, ignore_index=True)

    h_df.to_csv(f"{best_ensemble_training_path}/best_model_history_{model_idx}.csv", index=False)
# Out:
# Training model 0...
# 2022-05-11 10:52:28.947517: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-05-11 10:52:28.950763: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022
50
# 19/19 [==============================] - 4s 152ms/step - loss: 0.3849 - binary_accuracy: 0.8281 - val_loss: 0.4672 - val_binary_accuracy: 0.8008
# Epoch 14/50
# 19/19 [==============================] - 4s 147ms/step - loss: 0.3703 - binary_accuracy: 0.8436 - val_loss: 0.4414 - val_binary_accuracy: 0.8161
# Epoch 15/50
# 19/19 [==============================] - 4s 153ms/step - loss: 0.3821 - binary_accuracy: 0.8291 - val_loss: 0.5170 - val_binary_accuracy: 0.7567
# Epoch 16/50
# 19/19 [==============================] - 4s 149ms/step - loss: 0.3993 - binary_accuracy: 0.8224 - val_loss: 0.4599 - val_binary_accuracy: 0.7722
# Epoch 17/50
# 19/19 [==============================] - 4s 150ms/step - loss: 0.3524 - binary_accuracy: 0.8348 - val_loss: 0.4332 - val_binary_accuracy: 0.7649
# Epoch 18/50
# 19/19 [==============================] - 4s 174ms/step - loss: 0.3914 - binary_accuracy: 0.8082 - val_loss: 0.4825 - val_binary_accuracy: 0.7893
# Epoch 19/50
# 19/19 [==============================] - 4s 150ms/step - loss: 0.3980 - binary_accuracy: 0.8314 - val_loss: 0.4773 - val_binary_accuracy: 0.7416
# Epoch 20/50
# 19/19 [==============================] - 4s 155ms/step - loss: 0.3567 - binary_accuracy: 0.8309 - val_loss: 0.4870 - val_binary_accuracy: 0.7909
# Epoch 21/50
# 19/19 [==============================] - 4s 152ms/step - loss: 0.3375 - binary_accuracy: 0.8579 - val_loss: 0.4821 - val_binary_accuracy: 0.7940
# Epoch 22/50
# 19/19 [==============================] - 4s 161ms/step - loss: 0.3250 - binary_accuracy: 0.8595 - val_loss: 0.4803 - val_binary_accuracy: 0.7681
# Epoch 23/50
# 19/19 [==============================] - 4s 179ms/step - loss: 0.3385 - binary_accuracy: 0.8644 - val_loss: 0.4219 - val_binary_accuracy: 0.8286
# Epoch 24/50
# 19/19 [==============================] - 4s 155ms/step - loss: 0.3780 - binary_accuracy: 0.8496 - val_loss: 0.4690 - val_binary_accuracy: 0.7953
# Epoch 25/50
# 19/19 [==============================] - 4s 149ms/step - loss: 0.3346 - binary_accuracy: 0.8579 - val_loss: 0.5014 - val_binary_accuracy: 0.7603
# Epoch 26/50
# 19/19 [==============================] - 4s 151ms/step - loss: 0.3411 - binary_accuracy: 0.8719 - val_loss: 0.4125 - val_binary_accuracy: 0.7995
# Epoch 27/50
# 19/19 [==============================] - 4s 152ms/step - loss: 0.3408 - binary_accuracy: 0.8489 - val_loss: 0.4368 - val_binary_accuracy: 0.8037
# Epoch 28/50
# 19/19 [==============================] - 4s 163ms/step - loss: 0.3498 - binary_accuracy: 0.8496 - val_loss: 0.4034 - val_binary_accuracy: 0.8191
# Epoch 29/50
# 19/19 [==============================] - 4s 154ms/step - loss: 0.3303 - binary_accuracy: 0.8706 - val_loss: 0.4170 - val_binary_accuracy: 0.8063
# Epoch 30/50
# 19/19 [==============================] - 4s 151ms/step - loss: 0.
50
# 19/19 [==============================] - 4s 152ms/step - loss: 0.3879 - binary_accuracy: 0.8390 - val_loss: 0.4097 - val_binary_accuracy: 0.8075
# Epoch 16/50
# 19/19 [==============================] - 4s 150ms/step - loss: 0.3836 - binary_accuracy: 0.8219 - val_loss: 0.4279 - val_binary_accuracy: 0.8028
# Epoch 17/50
# 19/19 [==============================] - 4s 152ms/step - loss: 0.3596 - binary_accuracy: 0.8579 - val_loss: 0.3874 - val_binary_accuracy: 0.8409
# Epoch 18/50
# 19/19 [==============================] - 4s 168ms/step - loss: 0.3957 - binary_accuracy: 0.8233 - val_loss: 0.4067 - val_binary_accuracy: 0.8041
# Epoch 19/50
# 19/19 [==============================] - 4s 160ms/step - loss: 0.3865 - binary_accuracy: 0.8116 - val_loss: 0.3803 - val_binary_accuracy: 0.8611
# Epoch 20/50
# 19/19 [==============================] - 4s 149ms/step - loss: 0.3563 - binary_accuracy: 0.8281 - val_loss: 0.4264 - val_binary_accuracy: 0.8178
# Epoch 21/50
# 19/19 [==============================] - 4s 153ms/step - loss: 0.3934 - binary_accuracy: 0.8288 - val_loss: 0.3854 - val_binary_accuracy: 0.8426
# Epoch 22/50
# 19/19 [==============================] - 4s 152ms/step - loss: 0.3556 - binary_accuracy: 0.8393 - val_loss: 0.4080 - val_binary_accuracy: 0.7710
# Epoch 23/50
# 19/19 [==============================] - 6s 257ms/step - loss: 0.3496 - binary_accuracy: 0.8412 - val_loss: 0.3972 - val_binary_accuracy: 0.8110
# Epoch 24/50
# 19/19 [==============================] - 4s 158ms/step - loss: 0.3450 - binary_accuracy: 0.8462 - val_loss: 0.3894 - val_binary_accuracy: 0.8126
# Epoch 25/50
# 19/19 [==============================] - 4s 155ms/step - loss: 0.3473 - binary_accuracy: 0.8573 - val_loss: 0.3686 - val_binary_accuracy: 0.8253
# Epoch 26/50
# 19/19 [==============================] - 4s 166ms/step - loss: 0.3638 - binary_accuracy: 0.8461 - val_loss: 0.3679 - val_binary_accuracy: 0.8257
# Epoch 27/50
# 19/19 [==============================] - 4s 150ms/step - loss: 0.3451 - binary_accuracy: 0.8519 - val_loss: 0.3995 - val_binary_accuracy: 0.8180
# Epoch 28/50
# 19/19 [==============================] - 4s 154ms/step - loss: 0.3298 - binary_accuracy: 0.8631 - val_loss: 0.3756 - val_binary_accuracy: 0.8432
# Epoch 29/50
# 19/19 [==============================] - 4s 152ms/step - loss: 0.3493 - binary_accuracy: 0.8625 - val_loss: 0.3969 - val_binary_accuracy: 0.8110
# Epoch 30/50
# 19/19 [==============================] - 4s 147ms/step - loss: 0.3401 - binary_accuracy: 0.8569 - val_loss: 0.3868 - val_binary_accuracy: 0.8311
# Epoch 31/50
# 19/19 [==============================] - 4s 152ms/step - loss: 0.3116 - binary_accuracy: 0.8828 - val_loss: 0.3551 - val_binary_accuracy: 0.8490
# Epoch 32/50
# 19/19 [==============================] - 4s 151ms/step - loss: 0.
# Epoch 4/50
# 19/19 [==============================] - 6s 251ms/step - loss: 0.3636 - binary_accuracy: 0.8614 - val_loss: 0.4128 - val_binary_accuracy: 0.8286
# Epoch 5/50
# 19/19 [==============================] - 6s 256ms/step - loss: 0.2705 - binary_accuracy: 0.8645 - val_loss: 0.5174 - val_binary_accuracy: 0.8141
# Epoch 6/50
# 19/19 [==============================] - 6s 263ms/step - loss: 0.2740 - binary_accuracy: 0.8942 - val_loss: 0.4603 - val_binary_accuracy: 0.8088
# Epoch 7/50
# 19/19 [==============================] - 6s 252ms/step - loss: 0.3194 - binary_accuracy: 0.8695 - val_loss: 0.3966 - val_binary_accuracy: 0.8272
# Epoch 8/50
# 19/19 [==============================] - 6s 257ms/step - loss: 0.2587 - binary_accuracy: 0.8865 - val_loss: 0.3685 - val_binary_accuracy: 0.8593
# Epoch 9/50
# 19/19 [==============================] - 6s 259ms/step - loss: 0.3517 - binary_accuracy: 0.8545 - val_loss: 0.6028 - val_binary_accuracy: 0.7471
# Epoch 10/50
# 19/19 [==============================] - 6s 257ms/step - loss: 0.3048 - binary_accuracy: 0.8667 - val_loss: 0.3507 - val_binary_accuracy: 0.8676
# Epoch 11/50
# 19/19 [==============================] - 6s 255ms/step - loss: 0.2554 - binary_accuracy: 0.8970 - val_loss: 0.4138 - val_binary_accuracy: 0.8369
# Epoch 12/50
# 19/19 [==============================] - 6s 258ms/step - loss: 0.2336 - binary_accuracy: 0.8905 - val_loss: 0.5406 - val_binary_accuracy: 0.7698
# Epoch 13/50
# 19/19 [==============================] - 6s 271ms/step - loss: 0.2709 - binary_accuracy: 0.8893 - val_loss: 0.3571 - val_binary_accuracy: 0.8503
# Epoch 14/50
# 19/19 [==============================] - 6s 254ms/step - loss: 0.2272 - binary_accuracy: 0.8988 - val_loss: 0.5722 - val_binary_accuracy: 0.7802
# Epoch 15/50
# 19/19 [==============================] - 6s 260ms/step - loss: 0.1912 - binary_accuracy: 0.9250 - val_loss: 0.5076 - val_binary_accuracy: 0.8181
# Epoch 16/50
# 19/19 [==============================] - 6s 262ms/step - loss: 0.2958 - binary_accuracy: 0.8666 - val_loss: 0.3982 - val_binary_accuracy: 0.8203
# Epoch 17/50
# 19/19 [==============================] - 6s 255ms/step - loss: 0.2511 - binary_accuracy: 0.8916 - val_loss: 0.3872 - val_binary_accuracy: 0.8294
# Epoch 18/50
# 19/19 [==============================] - 8s 254ms/step - loss: 0.1937 - binary_accuracy: 0.9206 - val_loss: 0.4415 - val_binary_accuracy: 0.8545
# Epoch 19/50
# 19/19 [==============================] - 6s 263ms/step - loss: 0.1533 - binary_accuracy: 0.9287 - val_loss: 0.5519 - val_binary_accuracy: 0.7979
# Epoch 20/50
# 19/19 [==============================] - 6s 258ms/step - loss: 0.1562 - binary_accuracy: 0.9351 - val_loss: 0.6923 - val_binary_accuracy: 0.7719
# Epoch 21/50
# 19/19 [==============================] - 6s 259ms/step - loss: 0.2232 - binary_accuracy: 0.9013 - val_loss: 0.4074 - val_binary_accuracy: 0.8253
# Epoch 22/50
# 19/19 [==============================] - 6s 250ms/step - loss: 0.1741 - binary_accuracy: 0.9351 - val_loss: 0.4603 - val_binary_accuracy: 0.8105
# Epoch 23/50
# 19/19 [==============================] - 6s 257ms/step - loss: 0.1968 - binary_accuracy: 0.9305 - val_loss: 0.3581 - val_binary_accuracy: 0.8647
# Epoch 24/50
# 19/19 [==============================] - 6s 253ms/step - loss: 0.1607 - binary_accuracy: 0.9319 - val_loss: 0.5802 - val_binary_accuracy: 0.7940
# Epoch 25/50
# 19/19 [==============================] - 6s 261ms/step - loss: 0.2619 - binary_accuracy: 0.8768 - val_loss: 0.3437 - val_binary_accuracy: 0.8532
# Epoch 26/50
# 19/19 [==============================] - 6s 260ms/step - loss: 0.1944 - binary_accuracy: 0.9221 - val_loss: 0.3966 - val_binary_accuracy: 0.8467
# Epoch 27/50
# 19/19 [==============================] - 6s 261ms/step - loss: 0.1138 - binary_accuracy: 0.9580 - val_loss: 0.5202 - val_binary_accuracy: 0.8343
# Epoch 28/50
# 19/19 [==============================] - 6s 263ms/step - loss: 0.1692 - binary_accuracy: 0.9241 - val_loss: 0.5526 - val_binary_accuracy: 0.8272
# Epoch 29/50
# 19/19 [==============================] - 6s 258ms/step - loss: 0.1484 - binary_accuracy: 0.9432 - val_loss: 0.5183 - val_binary_accuracy: 0.8055
# Epoch 30/50
# 19/19 [==============================] - 6s 252ms/step - loss: 0.1409 - binary_accuracy: 0.9414 - val_loss: 0.5156 - val_binary_accuracy: 0.8470
# Epoch 31/50
# 19/19 [==============================] - 6s 264ms/step - loss: 0.1038 - binary_accuracy: 0.9552 - val_loss: 0.5753 - val_binary_accuracy: 0.8419
# Epoch 32/50
# 19/19 [==============================] - 6s 255ms/step - loss: 0.1485 - binary_accuracy: 0.9384 - val_loss: 0.4104 - val_binary_accuracy: 0.8312
# Epoch 33/50
# 19/19 [==============================] - 6s 252ms/step - loss: 0.1783 - binary_accuracy: 0.9187 - val_loss: 0.5081 - val_binary_accuracy: 0.8161
# Epoch 34/50
# 19/19 [==============================] - 8s 366ms/step - loss: 0.1604 - binary_accuracy: 0.9330 - val_loss: 0.4840 - val_binary_accuracy: 0.8580
# Epoch 35/50
# 19/19 [==============================] - 6s 265ms/step - loss: 0.0949 - binary_accuracy: 0.9594 - val_loss: 0.4716 - val_binary_accuracy: 0.8361
# Epoch 36/50
# 19/19 [==============================] - 6s 253ms/step - loss: 0.1250 - binary_accuracy: 0.9522 - val_loss: 0.5689 - val_binary_accuracy: 0.8544
# Epoch 37/50
# 19/19 [==============================] - 6s 261ms/step - loss: 0.1204 - binary_accuracy: 0.9533 - val_loss: 0.6283 - val_binary_accuracy: 0.8257
# Epoch 38/50
# 19/19 [==============================] - 6s 251ms/step - loss: 0.1296 - binary_accuracy: 0.9449 - val_loss: 0.4583 - val_binary_accuracy: 0.8274
# Epoch 39/50
# 19/19 [==============================] - 6s 259ms/step - loss: 0.0915 - binary_accuracy: 0.9674 - val_loss: 0.4948 - val_binary_accuracy: 0.7853
# Epoch 40/50
# 19/19 [==============================] - 6s 257ms/step - loss: 0.1242 - binary_accuracy: 0.9585 - val_loss: 0.5301 - val_binary_accuracy: 0.7831
# Epoch 41/50
# 19/19 [==============================] - 6s 263ms/step - loss: 0.1302 - binary_accuracy: 0.9509 - val_loss: 0.6185 - val_binary_accuracy: 0.8535
# Epoch 42/50
# 19/19 [==============================] - 6s 262ms/step - loss: 0.1026 - binary_accuracy: 0.9555 - val_loss: 0.6425 - val_binary_accuracy: 0.8282
# Epoch 43/50
# 19/19 [==============================] - 6s 252ms/step - loss: 0.0915 - binary_accuracy: 0.9616 - val_loss: 0.6316 - val_binary_accuracy: 0.8325
# Epoch 44/50
# 19/19 [==============================] - 6s 248ms/step - loss: 0.0963 - binary_accuracy: 0.9548 - val_loss: 0.5389 - val_binary_accuracy: 0.8481
# Epoch 45/50
# 19/19 [==============================] - 6s 259ms/step - loss: 0.1410 - binary_accuracy: 0.9422 - val_loss: 0.4745 - val_binary_accuracy: 0.8777
# Epoch 46/50
# 19/19 [==============================] - 6s 253ms/step - loss: 0.0843 - binary_accuracy: 0.9698 - val_loss: 0.9021 - val_binary_accuracy: 0.7735
# Epoch 47/50
# 19/19 [==============================] - 6s 261ms/step - loss: 0.1076 - binary_accuracy: 0.9413 - val_loss: 0.6572 - val_binary_accuracy: 0.7983
# Epoch 48/50
# 19/19 [==============================] - 6s 259ms/step - loss: 0.0839 - binary_accuracy: 0.9615 - val_loss: 0.6871 - val_binary_accuracy: 0.8502
# Epoch 49/50
# 19/19 [==============================] - 6s 261ms/step - loss: 0.0821 - binary_accuracy: 0.9712 - val_loss: 0.7664 - val_binary_accuracy: 0.7737
# Epoch 50/50
# 19/19 [==============================] - 6s 255ms/step - loss: 0.0598 - binary_accuracy: 0.9796 - val_loss: 0.6850 - val_binary_accuracy: 0.8473

# %% [markdown]
# # Look at history

# %%
# for model_idx in range(n_models):
# model_idx = 0
for model_idx in range(n_models):
    print(f"Model {model_idx} results: ")
    h_df = pd.read_csv(f"{best_ensemble_training_path}/best_model_history_{model_idx}.csv")
    ft_h_df = h_df.query("training_stage=='finetune'")
    print(f"Best train loss: {ft_h_df.loss.min()}")
    print(f"Best train acc: {ft_h_df.binary_accuracy.max()}")
    print(f"Best val loss: {ft_h_df.val_loss.min()}")
    print(f"Best val acc: {ft_h_df.val_binary_accuracy.max()}")
    print()
# Out:
# Model 0 results:
# Best train loss: 0.1112985089421272
# Best train acc: 0.950018048286438
# Best val loss: 0.3064514994621277
# Best val acc: 0.8875739574432373
#
# Model 1 results:
# Best train loss: 0.062589481472969
# Best train acc: 0.9745664596557616
# Best val loss: 0.2852932214736938
# Best val acc: 0.8526936769485474
#
# Model 2 results:
# Best train loss: 0.1044299378991127
# Best train acc: 0.9564787745475768
# Best val loss: 0.3060031831264496
# Best val acc: 0.8758629560470581
#
# Model 3 results:
# Best train loss: 0.1337691843509674
# Best train acc: 0.94807630777359
# Best val loss: 0.2941640615463257
# Best val acc: 0.8622913360595703
#
# Model 4 results:
# Best train loss: 0.0652048736810684
# Best train acc: 0.9736419916152954
# Best val loss: 0.3436527848243713
# Best val acc: 0.8776894807815552
